# %%
import pandas as pd
import os

# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# %%
os.getcwd()
# Out:
# '/Users/dhanaprakashdurairaj/Documents/GitHub/nba-player-analytics/Pre-processing/preprocessing_data'

# %%
# File to Load (Remember to change these)
player_stats_allyears_data_to_load = "../../Resources/PreprocessedDataFiles/NBAPlayersStatsAllYears.csv"
player_salary_allyears_data_to_load = "../../Resources/PreprocessedDataFiles/NBAPlayersSalaryAllYears.csv"

print(player_stats_allyears_data_to_load)
print(player_salary_allyears_data_to_load)
# Out:
# ../../Resources/PreprocessedDataFiles/NBAPlayersStatsAllYears.csv
# ../../Resources/PreprocessedDataFiles/NBAPlayersSalaryAllYears.csv

# %%
print(os.path.isfile(player_stats_allyears_data_to_load))
print(os.path.isfile(player_salary_allyears_data_to_load))
# Out:
# True
# True

# %%
# Read the Player Stat and Salary Data
player_stats_allyears_df = pd.read_csv(player_stats_allyears_data_to_load)
player_salary_allyears_df = pd.read_csv(player_salary_allyears_data_to_load)

# %%
# View Sats Dataframe
player_stats_allyears_df
# Out:
#       Unnamed: 0  Unnamed: 0.1  player_id  playing_season playing_position  \
# 0              0             0  abrinal01            2016               SG
# 1              1             1    acyqu01            2016               PF
# 2              2             4  adamsst01            2016                C
# 3              3             5  afflaar01            2016               SG
# 4              4             6  ajincal01            2016                C
# ...          ...           ...        ...             ...              ...
# 2080         524          6242  lavinza01            2019               SG
# 2081         525          6251  norveza01            2019               SG
# 2082         526          6269  smithzh01            2019               SF
# 2083         527          6273  willizi01            2019               PF
# 2084         528          6279  cheatzy01            2019               PF
#
#       playing_age team_name  no_of_games_played  no_minutes_played  \
# 0              23       OKC                  68               15.5
# 1              26       TOT                  38               14.7
# 2              23       OKC                  80               29.9
# 3              31       SAC                  61               25.9
# 4              28       NOP                  39               15.0
# ...           ...       ...                 ...                ...
# 2080           24       CHI                  60               34.8
# 2081           22       TOT                   5                8.2
# 2082           20       PHI                   7                4.6
# 2083           19       NOP                  24               27.8
# 2084           24       NOP                   4               12.8
#
#       field_goals_made  ...  three_point_pctg  effective_field_goal_pctg  \
# 0                  2.0  ...             0.381                      0.531
# 1                  1.8  ...             0.411                      0.521
# 2                  4.7  ...             0.000                      0.571
# 3                  3.0  ...             0.411                      0.514
# 4                  2.3  ...             0.000                      0.500
# ...                ...  ...               ...                        ...
# 2080               9.0  ...             0.380                      0.526
# 2081               0.6  ...             0.375                      0.375
# 2082               0.4  ...             0.000                      0.273
# 2083               8.8  ...             0.429                      0.592
# 2084               1.5  ...             0.000                      0.667
#
#       free_thows_made  free_throws_pctg  total_rebounds  no_of_assists  \
# 0                 0.6             0.898             1.3            0.6
# 1                 1.2             0.750             3.0            0.5
# 2                 2.0             0.611             7.7            1.1
# 3                 1.4             0.892             2.0            1.3
# 4                 0.7             0.725             4.5            0.3
# ...               ...               ...             ...            ...
# 2080              4.5             0.802             4.8            4.2
# 2081              0.2             1.000             1.2            0.6
# 2082              0.3             0.500             0.3            0.3
# 2083              4.8             0.640             6.3            2.1
# 2084              0.0             0.000             2.3            0.8
#
#       no_of_steals  no_of_blocks  no_of_turnovers  points
# 0              0.5           0.1              0.5     6.0
# 1              0.4           0.4              0.6     5.8
# 2              1.1           1.0              1.8    11.3
# 3              0.3           0.1              0.7     8.4
# 4              0.5           0.6              0.8     5.3
# ...            ...           ...              ...     ...
# 2080           1.5           0.5              3.4    25.5
# 2081           0.4           0.0              0.6     2.0
# 2082           0.4           0.0              0.3     1.1
# 2083           0.7           0.4              2.5    22.5
# 2084           0.3           0.3              1.0     3.0
#
# [2085 rows x 22 columns]

# %%
# View Salary Dataframe
player_salary_allyears_df
# Out:
#       Unnamed: 0  Unnamed: 0.1  player_id  playing_season     salary
# 0              0             0  hammoaj01          2016.0        0.0
# 1              1             1  brookaa01          2016.0  2700000.0
# 2              2             2  gordoaa01          2016.0  4351320.0
# 3              3             3  paynead01          2016.0  2022240.0
# 4              4             4  aminual01          2016.0  7680965.0
# ...          ...           ...        ...             ...        ...
# 1929         521           521  youngtr01       6273000.0     2019.0
# 1930         522           522  zelleco01      14471910.0     2019.0
# 1931         523           523  zellety01        245686.0     2019.0
# 1932         524           524  zizican01       2281800.0     2019.0
# 1933         525           525  zubaciv01       6481482.0     2019.0
#
# [1934 rows x 5 columns]

# %%
player_stats_allyears_df['player_id'].value_counts()
# Out:
# wiggian01    4
# thomais02    4
# schrode01    4
# hernaju01    4
# wrighde01    4
#             ..
# ellismo01    1
# siberjo01    1
# munfoxa02    1
# owensta01    1
# morgaju01    1
# Name: player_id, Length: 864, dtype: int64
